# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import importlib.util

# Load utilities from local utils.py file
spec = importlib.util.spec_from_file_location("utils", os.path.join(os.getcwd(), "utils.py"))
utils = importlib.util.module_from_spec(spec)
spec.loader.exec_module(utils)

# Import the functions we need
load_data = utils.load_data
mape = utils.mape
create_evaluation_df = utils.create_evaluation_df
TimeSeriesTensor = utils.TimeSeriesTensor

# %matplotlib inline
